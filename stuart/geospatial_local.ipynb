# %%
from sqlalchemy import create_engine
import pandas as pd
import json
from MyCreds.mycreds import Capstone_Local       #from local site-packages

engine = create_engine(f'postgresql+psycopg2://{Capstone_Local.username}:{Capstone_Local.password}@{Capstone_Local.host}/postgres', echo=False)

sql_alc_cnxn = engine.connect()

# %% [markdown]
# # Load Data into local DB
#
# We use the postal code database to do the set-up

# %%
# load data from JSON
postal = 'buildings.json'
df_postal = pd.read_json(postal)

# upload to AWS
df_postal.to_sql('postal',sql_alc_cnxn, if_exists='replace', index=False)

# %%
# check to ensure it is set up right
sql_query ='''
select * from public."postal";
'''
df = pd.read_sql(sql_query, sql_alc_cnxn)
df.sample()
# Out:
#                                                   ADDRESS BLK_NO  \
# 122208  475 CHOA CHU KANG AVENUE 3 KITS4KIDS SPECIAL S...    475
#
#                         BUILDING  LATITUDE   LONGITUDE  LONGTITUDE  POSTAL  \
# 122208  KITS4KIDS SPECIAL SCHOOL  1.377968  103.739176  103.739176  680475
#
#                      ROAD_NAME                 SEARCHVAL             X  \
# 122208  CHOA CHU KANG AVENUE 3  KITS4KIDS SPECIAL SCHOOL  17523.064547
#
#                    Y                                           location
# 122208  39994.462596  0101000020110F0000705E8F8C280CF63F0DCB73A74EEF...

# %% [markdown]
# # Setting up PostGIS in AWS
#
# We follow steps from [this documentation](https://docs.aws.amazon.com/AmazonRDS/latest/UserGuide/Appendix.PostgreSQL.CommonDBATasks.PostGIS.html) to setup/activate the PostGIS extention
#
# Run queries in PGAdmin
#
# Ensure that the rds_superuser role (user name that was used to create the DB instance) is selected
#
# # Next set up a spatial table in the database
#
# 2 Main Steps
# 1. Create a normal non-spatial table/use existing
# 2. Add a spatial column to the table using the OpenGIS "AddGeometryColumn" function.
#
# But we since we have lat-long in the database we can just use that

# %%
sql_query ='''
ALTER TABLE public."postal" ADD COLUMN location GEOMETRY(point, 3857);
UPDATE public."postal" SET location = ST_SETSRID(ST_MakePoint("LATITUDE","LONGITUDE"),3857);
'''
sql_alc_cnxn.execute(sql_query)

# %% [markdown]
# Check to ensure location was loaded

# %%
sql_query ='''
select * from public."postal";
'''
df = pd.read_sql(sql_query, sql_alc_cnxn)
df
# Out:
#                                                   ADDRESS   BLK_NO  \
# 0       101A BAYFRONT AVENUE TEMPORARY SITE OFFICE SIN...     101A
# 1       1 STRAITS BOULEVARD SINGAPORE CHINESE CULTURAL...        1
# 2       11A STRAITS BOULEVARD TEMPORARY SITE OFFICE SI...      11A
# 3       2 CENTRAL BOULEVARD IOI CENTRAL BOULEVARD TOWE...        2
# 4       21 PARK STREET DBS MARINA BAY MRT STATION SING...       21
# ...                                                   ...      ...
# 142881                  100A KRANJI LOOP SINGAPORE 887327     100A
# 142882              A PASIR PANJANG ROAD SINGAPORE 887328        A
# 142883                       PULAU BUKOM SINGAPORE 903808
# 142884  GATE C7 AIRPORT CARGO ROAD CHANGI ANIMAL AND P...  GATE C7
# 142885  AIRPORT BOULEVARD CHANGI AIRPORT TERMINAL 2 BU...
#
#                                          BUILDING  LATITUDE   LONGITUDE  \
# 0                           TEMPORARY SITE OFFICE  1.275697  103.855652
# 1               SINGAPORE CHINESE CULTURAL CENTRE  1.275829  103.849576
# 2                           TEMPORARY SITE OFFICE  1.274950  103.851665
# 3                    IOI CENTRAL BOULEVARD TOWERS  1.279777  103.851513
# 4                      DBS MARINA BAY MRT STATION  1.276427  103.854598
# ...                                           ...       ...         ...
# 142881                                        NIL  1.433629  103.758648
# 142882                                        NIL  1.277170  103.795840
# 142883                                        NIL  1.235596  103.768645
# 142884  CHANGI ANIMAL AND PLANT QUARANTINE CENTRE  1.375285  103.996737
# 142885         CHANGI AIRPORT TERMINAL 2 BUILDING  1.354969  103.989066
#
#         LONGTITUDE  POSTAL           ROAD_NAME  \
# 0       103.855652   18895     BAYFRONT AVENUE
# 1       103.849576   18906   STRAITS BOULEVARD
# 2       103.851665   18907   STRAITS BOULEVARD
# 3       103.851513   18916   CENTRAL BOULEVARD
# 4       103.854598   18925         PARK STREET
# ...            ...     ...                 ...
# 142881  103.758648  887327         KRANJI LOOP
# 142882  103.795840  887328  PASIR PANJANG ROAD
# 142883  103.768645  903808         PULAU BUKOM
# 142884  103.996737  918104  AIRPORT CARGO ROAD
# 142885  103.989066  918146   AIRPORT BOULEVARD
#
#                                         SEARCHVAL             X             Y  \
# 0                           TEMPORARY SITE OFFICE  30485.511362  28685.612665
# 1               SINGAPORE CHINESE CULTURAL CENTRE  29809.365407  28700.236127
# 2                           TEMPORARY SITE OFFICE  30041.838898  28602.987244
# 3                    IOI CENTRAL BOULEVARD TOWERS  30024.919852  29136.807026
# 4                      DBS MARINA BAY MRT STATION  30368.205612  28766.381902
# ...                                           ...           ...           ...
# 142881          100A KRANJI LOOP SINGAPORE 887327  19690.280996  46149.118386
# 142882      A PASIR PANJANG ROAD SINGAPORE 887328  23828.902741  28848.553424
# 142883               PULAU BUKOM SINGAPORE 903808  20802.263821  24251.557450
# 142884  CHANGI ANIMAL AND PLANT QUARANTINE CENTRE  46186.488419  39698.194002
# 142885         CHANGI AIRPORT TERMINAL 2 BUILDING  45332.984096  37451.702888
#
#                                                  location
# 0       0101000020110F00004BC54D264169F43FC685CAFFC2F6...
# 1       0101000020110F000013AF0BDFCB69F43F8F26A5755FF6...
# 2       0101000020110F00007A735AA63166F43F37F1EDAE81F6...
# 3       0101000020110F0000960CD0D6F779F43FB11B70317FF6...
# 4       0101000020110F0000AA1D07173F6CF43F2399DFBAB1F6...
# ...                                                   ...
# 142881  0101000020110F00008F5DBB7B25F0F63FDCF8F2AF8DF0...
# 142882  0101000020110F0000E717771F4A6FF43F7788C209EFF2...
# 142883  0101000020110F0000B486DF7800C5F33F19D2057C31F1...
# 142884  0101000020110F00005B6A881C2B01F63FB09F7E8ACAFF...
# 142885  0101000020110F0000A7C6FE5FF4ADF53F00CC88DD4CFF...
#
# [142886 rows x 12 columns]

# %%
# some test points from google maps
CBD = ('1.2790515225747496', '103.85402179404132')
Tiong_Bahru = ('1.2863988893455323', '103.82509579340865')

# %% [markdown]
# # Test spatial queries
#
# Next we can query distances to popular locations in Singapore to each address location
#
# Note ST_Distance is returning in degrees so we have to x111239.6925397 to convert this to meters

# %%
sql_query ='''
SELECT
    "ADDRESS",
    ST_Distance(
            "location",
            ST_GeomFromText('POINT(1.279177928627326 103.85462727093415)',3857)
            )*111239.6825397 as m_to_CBD,
    ST_Distance(
            "location",
            ST_GeomFromText('POINT(1.2863988893455323 103.82509579340865)',3857)
            )*111239.6825397 as m_to_tiongbahru
    FROM public."postal";
'''
df = pd.read_sql(sql_query, sql_alc_cnxn)
df.sample(20)
# Out:
#                                                   ADDRESS      m_to_cbd  \
# 70380                3 EVERGREEN GARDENS SINGAPORE 468879   9713.310132
# 41732   1A MELROSE DRIVE BRADDELL HEIGHTS ESTATE SINGA...   7722.773119
# 44233                    34 CIRCUIT ROAD SINGAPORE 370034   6640.118674
# 135378  31 FERNVALE CLOSE RIVERTREES RESIDENCES SINGAP...  13025.309484
# 22847                   1B STEVENS DRIVE SINGAPORE 257890   5268.058986
# 134556         61 LENTOR GROVE FUDU PARK SINGAPORE 789221  12152.648911
# 61350        722 DUNMAN ROAD ZEE JUNIORS SINGAPORE 439235   5965.225549
# 48916   1077 EUNOS AVENUE 6 EUNOS INDUSTRIAL ESTATE SI...   6559.330693
# 40779   83 GENTING LANE GENTING BUILDING SINGAPORE 349568   5825.856170
# 110228  24 TOH GUAN ROAD EAST WESTLITE TOH GUAN DORMIT...  13060.235806
# 82820                28 TAI KENG GARDENS SINGAPORE 535309   8281.175004
# 108002                 126 LORONG KISMIS SINGAPORE 598051  11565.067293
# 74196     17 HARVEY CRESCENT HARVEY VIEW SINGAPORE 489379  13063.680290
# 61342                    713 DUNMAN ROAD SINGAPORE 439230   5902.119116
# 25000              45 OEI TIONG HAM PARK SINGAPORE 267050   8053.908322
# 97701   2 ANG MO KIO DRIVE CARPE DIEM @ ITE PTE. LTD. ...  10982.721026
# 3839                  22 KEONG SAIK ROAD SINGAPORE 089129   1444.745570
# 27243     35 BIN TONG PARK BIN TONG PARK SINGAPORE 269816   7778.263497
# 106622   14 YUK TONG AVENUE AIRVIEW PARK SINGAPORE 596319  11326.856531
# 21307                 6A SWETTENHAM ROAD SINGAPORE 248086   6196.258484
#
#         m_to_tiongbahru
# 70380      12557.423144
# 41732       8129.366010
# 44233       8402.190448
# 135378     13412.522608
# 22847       3414.493372
# 134556     11307.015630
# 61350       8608.430992
# 48916       8750.832509
# 40779       7272.093142
# 110228      9837.076851
# 82820       9452.122568
# 108002      8442.585610
# 74196      15623.730311
# 61342       8512.676117
# 25000       4900.228341
# 97701      10757.343432
# 3839        1974.357177
# 27243       4873.205452
# 106622      8377.738611
# 21307       3029.085599

# %% [markdown]
# Alternatively, instead of creating the point, we can also use the function ST_MakePoint() to create the point from latitude and longitude columns

# %%
sql_query ='''
SELECT
    "ADDRESS",
    ST_Distance(
            ST_SETSRID(ST_MakePoint("LATITUDE","LONGITUDE"),3857),
            ST_GeomFromText('POINT(1.279177928627326 103.85462727093415)',3857)
            )*111239.6825397 as m_to_CBD,
    ST_Distance(
            ST_SETSRID(ST_MakePoint("LATITUDE","LONGITUDE"),3857),
            ST_GeomFromText('POINT(1.2863988893455323 103.82509579340865)',3857)
            )*111239.6825397 as m_to_tiongbahru
    FROM public."postal";
'''
df = pd.read_sql(sql_query, sql_alc_cnxn)
df.sample(20)
# Out:
#                                                   ADDRESS      m_to_cbd  \
# 85412   3B CHARLTON ROAD CHARLTON RESIDENCES SINGAPORE...   9028.189551
# 109857  38 TOH TUCK PLACE TOH TUCK GARDEN SINGAPORE 59...  11895.874264
# 51619                    276 CHANGI ROAD SINGAPORE 419756   7159.096469
# 110999           2A SECOND CHIN BEE ROAD SINGAPORE 618781  16586.391865
# 64632   31 JALAN BULOH PERINDU SEASIDE PARK SINGAPORE ...   8028.480395
# 31127         40 WATTEN VIEW WATTEN HILL SINGAPORE 287167   7643.521987
# 109182  535 CLEMENTI ROAD NGEE ANN POLYTECHNIC (BLK 43...  10995.906297
# 81442                    23 THRIFT DRIVE SINGAPORE 535032   7806.936276
# 81957   221 AIRPORT ROAD PAYA LEBAR AIR BASE SINGAPORE...   8786.603323
# 138613    41 SUNRISE CLOSE SUNRISE VILLA SINGAPORE 806638  11994.563856
# 25474                   5 KINGSMEAD ROAD SINGAPORE 267960   7145.168792
# 95446   29 CONWAY GROVE SERANGOON GARDEN ESTATE SINGAP...   8924.490176
# 129042  1068 SEMBAWANG ROAD SEMBAWANG STRAITS ESTATE S...  19817.068351
# 139596  42 NERAM ROAD SELETAR HILLS ESTATE SINGAPORE 8...  12036.410084
# 95705     14 CHUAN TERRACE CHUAN TERRACE SINGAPORE 558482   9416.156689
# 46312   722 GEYLANG ROAD GEYLANG CONSERVATION AREA SIN...   5708.290330
# 16078                   415B JALAN BESAR SINGAPORE 209016   3921.866778
# 123697  118A PLANTATION CRESCENT PLANTATION GROVE SING...  15721.594349
# 135927  70 LORONG TANGGAM JALAN KAYU ESTATE SINGAPORE ...  13241.576486
# 44259   18 LORONG 37 GEYLANG NTWU BUILDING SINGAPORE 3...   5705.740029
#
#         m_to_tiongbahru
# 85412       9932.231249
# 109857      8791.208420
# 51619       9672.787595
# 110999     13234.294866
# 64632      10908.218289
# 31127       5241.852854
# 109182      7877.946668
# 81442       9077.128907
# 81957      10511.354880
# 138613     11701.148855
# 25474       4324.365339
# 95446       9208.787737
# 129042     18927.295944
# 139596     12119.627718
# 95705       9712.469946
# 46312       8041.610880
# 16078       4942.654455
# 123697     12571.887471
# 135927     13404.019526
# 44259       7954.169065

# %% [markdown]
# ## Sanity Checking
#
# Results look more or less inline with what we can get from a good map - precision is off as the selected points on the map are not precise
#
# ![query_results](query_res.png)
# ![dist_to_cbd](dist_to_cbd.png)
# ![dist_to_tiongbahru](dist_to_tiongbahru.png)

# %% [markdown]
# ## Load MRT/LRT Data

# %%
df_transit = pd.read_csv('lta-mrt-station-exit/mrt_lrt_data.csv')

# %%
df_transit.to_sql('transit',sql_alc_cnxn, if_exists='replace', index=False)

# %%
sql_query ='''
ALTER TABLE public."transit" ADD COLUMN location GEOMETRY(point, 3857);
UPDATE public."transit" SET location = ST_SETSRID(ST_MakePoint("lat","lng"),3857);
'''
sql_alc_cnxn.execute(sql_query)

# %%
sql_query ='''
select * from public."transit";
'''
df = pd.read_sql(sql_query, sql_alc_cnxn)
df
# Out:
#       station_name type       lat         lng  \
# 0      Jurong East  MRT  1.333207  103.742308
# 1      Bukit Batok  MRT  1.349069  103.749596
# 2     Bukit Gombak  MRT  1.359043  103.751863
# 3    Choa Chu Kang  MRT  1.385417  103.744316
# 4          Yew Tee  MRT  1.397383  103.747523
# ..             ...  ...       ...         ...
# 152  Punggol Point  LRT  1.416932  103.906680
# 153       Samudera  LRT  1.415955  103.902185
# 154         Nibong  LRT  1.411865  103.900321
# 155         Sumang  LRT  1.408501  103.898605
# 156       Soo Teck  LRT  1.405436  103.897287
#
#                                               location
# 0    0101000020110F0000B9C5FCDCD054F53FC9E369F981EF...
# 1    0101000020110F000040C23060C995F53F984D8061F9EF...
# 2    0101000020110F000041B96DDFA3BEF53FA304FD851EF0...
# 3    0101000020110F0000AE282504AB2AF63FEE7893DFA2EF...
# 4    0101000020110F00002AC8CF46AE5BF63F8080B56AD7EF...
# ..                                                 ...
# 152  0101000020110F0000747E8AE3C0ABF63FFCFB8C0B07FA...
# 153  0101000020110F00000FB9196EC0A7F63F467C2766BDF9...
# 154  0101000020110F000065DF15C1FF96F63FBBB9F8DB9EF9...
# 155  0101000020110F0000FB2136583889F63F6AC18BBE82F9...
# 156  0101000020110F0000D8EF8975AA7CF63F100874266DF9...
#
# [157 rows x 5 columns]

# %%
sql_query ='''
SELECT
    a."ADDRESS",
    count(b.*) as station_count
    FROM public."postal" a, public."transit" b
    WHERE ST_DWithin(a."location",b."location",600/111239.6825397) 
    GROUP BY a."ADDRESS" 
'''
df = pd.read_sql(sql_query, sql_alc_cnxn)
df.sample(20)
# Out:
#                                                  ADDRESS  station_count
# 16133  22 JALAN NOVENA RESIDENCES @ NOVENA SINGAPORE ...              1
# 12107                  1A LORONG SARINA SINGAPORE 416646              1
# 34141                  49 KIM PONG ROAD SINGAPORE 160049              1
# 30003    406 DUNEARN ROAD WATTEN ESTATE SINGAPORE 289611              2
# 25450  33 EVERTON ROAD BLAIR PLAIN CONSERVATION AREA ...              1
# 17129  23 SAINT THOMAS WALK SAM KIANG MANSIONS SINGAP...              1
# 6534                 146 MACKENZIE ROAD SINGAPORE 228723              1
# 18679      260 BEDOK ROAD SIEW LIM PARK SINGAPORE 469427              1
# 6471   145A TYRWHITT ROAD PETAIN ROAD/TYRWHITT ROAD C...              3
# 24466  323 ANG MO KIO AVENUE 3 CHENG SAN FAMILY SERVI...              1
# 36209  520 LORONG 6 TOA PAYOH UOB TOA PAYOH BRANCH SI...              1
# 28043    38A JALAN PAKIS CHESTNUT-VILLE SINGAPORE 678623              1
# 17346                   246 JALAN BESAR SINGAPORE 208919              3
# 11196        18 WATTEN VIEW WATTEN HILL SINGAPORE 287136              1
# 18344                  25 GILSTEAD ROAD SINGAPORE 309070              1
# 23120  30 CHOON GUAN STREET CITY SOUTH TELEPHONE EXCH...              1
# 35525  50 LORONG MARICAN KEMBANGAN ESTATE SINGAPORE 4...              1
# 7808   15 ANN SIANG ROAD TELOK AYER CONSERVATION AREA...              3
# 22078              2 JALAN PUTEH JERNEH SINGAPORE 278026              1
# 36933                    53 SING AVENUE SINGAPORE 217895              1

# %%
df[df['ADDRESS'].str.contains('COMPASSVALE CRESCENT')]
# Out:
#                                                  ADDRESS  station_count
# 20901  290A COMPASSVALE CRESCENT COMPASSVALE LODGE SI...              1
# 20902  290A COMPASSVALE CRESCENT PCF SPARKLETOTS PRES...              1
# 20909  290 COMPASSVALE CRESCENT MULTI STOREY CAR PARK...              1
# 20950  293A COMPASSVALE CRESCENT COMPASSVALE BOARDWAL...              1
# 20955  293B COMPASSVALE CRESCENT COMPASSVALE BOARDWAL...              1
# 20957  293 COMPASSVALE CRESCENT COMPASSVALE BOARDWALK...              1
# 20958  293D COMPASSVALE CRESCENT COMPASSVALE BOARDWAL...              1
# 20968  294A COMPASSVALE CRESCENT COMPASSVALE BOARDWAL...              1
# 20973          294 COMPASSVALE CRESCENT SINGAPORE 540294              1
