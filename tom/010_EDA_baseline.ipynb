# %% [markdown]
# <br>

# %%
#  Name:      Tom Bresee
#  Purpose:   EDA
#  Dataset:   Base Normalized but not geo-spatial features yet
#  Project:   Capstone

# %% [markdown]
# <br>

# %% [markdown]
# *View this notebook online via this link (easy to see)*

# %% [markdown]
# <br>

# %% [markdown]
# *Utility Functions:*

# %%
def my_columns(df):
    """Print out columns from input dataframe"""
    for col in df.columns:
        print(col)
              
            
def my_null_per_col(column_name):
    print(df[column_name].isna().sum())
      
        
def my_null_all():
    """NaN for entire dataframe"""
    print(df.isna().sum())
    
    
def my_dup_rows_count():
    print(df.duplicated().sum())  
    # 1863 ? 
    
    
def kill_kolumns(list_of_columns):
    df.drop(list_of_columns, axis=1, inplace=True) 
    
    
def is_categorical(col):
    return df[col].dtype.name == 'object'


def quick_vc_bar(col):
    """ 
    input column
    output histogram of counts
    """
    print('Value Counts Histogram:', col)
    df[col].value_counts().plot(kind='bar', 
                                color='navy',
                                alpha=0.6,
                                figsize=(8,6));
    
        

def replace_values_in_col(col, mapping_dict):
    replace_values = mapping_dict
    df = df.replace({col: replace_values})

    
def the_columns(df):
    """sorted list of df columns"""
    for c in sorted(list(df.columns)):
        print(c)
        

def encode_and_bind(my_original_dataframe, feature_to_encode):
    dummies = pd.get_dummies(my_original_dataframe[[feature_to_encode]])
    resulting_df = pd.concat([my_original_dataframe, dummies], axis=1)
    return(resulting_df)

# remove original feature at same time (slight variation):
# def encode_and_bind(original_dataframe, feature_to_encode):
#     dummies = pd.get_dummies(original_dataframe[[feature_to_encode]])
#     res = pd.concat([original_dataframe, dummies], axis=1)
#     res = res.drop([feature_to_encode], axis=1)
#     return(res) 

# total number of NaNs completed summed in a pd df:
# df.isnull().sum().sum()

# df.transaction_id.value_counts()
# print(df.duplicated().sum())
# print(df.duplicated(keep='last'))
# print(df.duplicated().sum())
# 
# limit to categorical data using df.select_dtypes()
# X = X.select_dtypes(include=[object])

# from sklearn.preprocessing import OneHotEncoder
# ohe = OneHotEncoder()
# ohe.fit_transform()
# ohe.fit_transform(  df[['sex']])
# ohe.categories_

# %% [markdown]
# <br>

# %% [markdown]
# *Libraries:*

# %%
# --------------------------------------------------------------------------
from mycreds import Capstone_AWS_RO
# --------------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
# --------------------------------------------------------------------------
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format) 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# --------------------------------------------------------------------------
import glob  
from datetime import datetime as dt
import pandas_profiling
from pandas_profiling import ProfileReport
# from bokeh.layouts import column
# from bokeh.models import Div, TeX
# from bokeh.plotting import figure, show
# from bokeh.io import output_notebook
# --------------------------------------------------------------------------
import fiona
from sqlalchemy import create_engine
# output_notebook() # bokeh
# --------------------------------------------------------------------------
from sklearn.model_selection import train_test_split, KFold, cross_val_score 
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder, PolynomialFeatures
from sklearn.preprocessing import RobustScaler, LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import mean_absolute_error, recall_score
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import Pipeline
from sklearn.metrics import explained_variance_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neural_network import MLPRegressor
import xgboost as xgb
cm = sns.light_palette("blue", as_cmap=True)
# correlations.style.set_caption('Correlation Values Ranked').background_gradient(cmap=cm)
# --------------------------------------------------------------------------
import shap
shap.initjs()
# Out:
# <style>.container { width:100% !important; }</style>
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# <br>

# %% [markdown]
# *Download raw data from AWS database:*

# %% [markdown]
# ```
# Database Views:
# resale_price_norm  - transactions WITHOUT location features
# resale_location_features  - transactions WITH location features
# ```

# %%
# # query = 'select * from conservation_areas limit 1;'
# query = 'select * from resale_price_norm;'
# # query = 'select * from resale_location_features limit 1;'
# engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{host}/Capstone', echo=False)
# # /Capstone vs original /capstone
# sql_alc_cnxn = engine.connect()
# df = pd.read_sql(query, sql_alc_cnxn)
# df.to_pickle("resale_price_norm.pkl")
# query2 = 'select * from resale_location_features;'
# engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{host}/Capstone', echo=False)
# sql_alc_cnxn = engine.connect()
# df2 = pd.read_sql(query2, sql_alc_cnxn)
# 1093117
# df2.to_pickle("resale_location_features_GOLD.pkl")

# %%
# query = 'select * from conservation_areas limit 1;'
# query = 'select * from resale_location_features limit 1;'

query = 'select * from resale_price_norm;'

# engine = create_engine(f'postgresql+psycopg2://{Capstone_AWS_RO.username}:{Capstone_AWS_RO.password}@{Capstone_AWS_RO.host}/Capstone', echo=False)
# engine = create_engine(f'postgresql+psycopg2://{Capstone_AWS_RO.username}:{Capstone_AWS_RO.password}@{Capstone_AWS_RO.host}/Capstone', echo=False)
    
# - original - 
engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{host}/Capstone', echo=False)

sql_alc_cnxn = engine.connect()

# %%
df = pd.read_sql(query, sql_alc_cnxn)  
# doesn't take a terribly long time

# %%
original_number_of_observations = len(df)

# %%
original_number_of_observations
# Out:
# 867677

# %%
len(df)  # ~ 867,677
# Out:
# 867677

# %% [markdown]
# <br>

# %% [markdown]
# *Pickle if you want (in case no access to DB):*

# %%
df.to_pickle('resale_price_norm_GOLD.pkl')  # ~ 232 MB
# compression  {‘infer’, ‘gzip’, ‘bz2’, ‘zip’, ‘xz’, None}
# will overwrite old file fyi

# %% [markdown]
# *Read in previously downloaded .pkl of entire raw dataset, if desired:*

# %%
# new_df = pd.read_pickle('resale_price_norm_GOLD.pkl')

# %% [markdown]
# <br>

# %%
len(df.columns)  # ~ 27 columns/features
# Out:
# 27

# %%
original_df = df.copy()

# %% [markdown]
# <br>

# %% [markdown]
# *Storing raw data (unfiltered) in zipped (.csv embedded) form:*

# %%
compression_opts = dict(method='zip', 
                        archive_name='resale_price_norm_GOLD.csv')

df.to_csv('resale_price_norm_GOLD.zip', 
          index=False, 
          compression=compression_opts)

# %% [markdown]
# The full exported data to .csv is a large file: 270 MB. Even when the file is compressed (.zip) it is still: ~ 83 MB.

# %% [markdown]
# <br>

# %% [markdown]
# *Storing raw data (unfiltered) in parquet form:*

# %%
#  df.to_parquet('df.parquet.gzip', compression='gzip') 
#  s3_url = 's3://bucket/folder/bucket.parquet.gzip'  
#  s3 bucket works as well

#  df.to_parquet(s3_url, compression='gzip')

# %%
df.to_parquet('resale_price_norm_GOLD.parquet.gzip', compression='gzip')  
# parquet + compressed gzip form in the event files are huge
# and then can use: pd.read_parquet('df.parquet.gzip') to read the contents...

# %%
df.to_parquet('resale_price_norm_GOLD.parquet', engine='fastparquet')  
#  standard parquet form exported

# %% [markdown]
# *Read-in parquet form (if needed):*

# %%
# IF you wanted to read, and its pretty darn fast:
#  tf = pd.read_parquet('resale_price_norm_GOLD.parquet', engine='fastparquet')

# %% [markdown]
# <br>

# %% [markdown]
# *Quick checks:*

# %%
df.dtypes
# Out:
# transaction_id                               object
# month                                datetime64[ns]
# block                                        object
# town                                         object
# street_name                                  object
# address                                      object
# storey_range                                 object
# storey_range_min                              int64
# storey_range_max                              int64
# flat_model                                   object
# flat_type                                    object
# n_rooms                                       int64
# floor_area_sqm                              float64
# lease_commence_date                           int64
# remaining_lease                              object
# remaining_lease_years                         int64
# remaining_lease_months                      float64
# resale_price                                float64
# price_per_sq_ft                             float64
# price_per_sq_m                              float64
# price_per_sq_ft_per_lease_yr                float64
# price_per_sq_m_per_lease_yr                 float64
# resale_price_norm                           float64
# price_per_sq_ft_norm                        float64
# price_per_sq_ft_per_lease_yr_norm           float64
# price_per_sq_m_norm                         float64
# price_per_sq_m_per_lease_yr_norm            float64
# dtype: object

# %%
df.head(1).T  # random example datapoint
# Out:
#                                                                       0
# transaction_id                     2004_06_545_WOODLANDS_DR_16_07_TO_09
# month                                               2004-06-01 00:00:00
# block                                                               545
# town                                                          WOODLANDS
# street_name                                             WOODLANDS DR 16
# address                                             545 WOODLANDS DR 16
# storey_range                                                   07 TO 09
# storey_range_min                                                      7
# storey_range_max                                                      9
# flat_model                                                      Model A
# flat_type                                                        4 ROOM
# n_rooms                                                               4
# floor_area_sqm                                                   100.00
# lease_commence_date                                                2000
# remaining_lease                                                    None
# remaining_lease_years                                                94
# remaining_lease_months                                              NaN
# resale_price                                                  229300.00
# price_per_sq_ft                                                  698.91
# price_per_sq_m                                                  2293.00
# price_per_sq_ft_per_lease_yr                                       7.44
# price_per_sq_m_per_lease_yr                                       24.39
# resale_price_norm                                             453183.46
# price_per_sq_ft_norm                                            1381.30
# price_per_sq_ft_per_lease_yr_norm                                 14.69
# price_per_sq_m_norm                                             4531.83
# price_per_sq_m_per_lease_yr_norm                                  48.21

# %%
df.tail(1).T  # random example datapoint
# Out:
#                                                                  867676
# transaction_id                     2004_06_546_WOODLANDS_DR_16_01_TO_03
# month                                               2004-06-01 00:00:00
# block                                                               546
# town                                                          WOODLANDS
# street_name                                             WOODLANDS DR 16
# address                                             546 WOODLANDS DR 16
# storey_range                                                   01 TO 03
# storey_range_min                                                      1
# storey_range_max                                                      3
# flat_model                                                      Model A
# flat_type                                                        4 ROOM
# n_rooms                                                               4
# floor_area_sqm                                                   100.00
# lease_commence_date                                                2000
# remaining_lease                                                    None
# remaining_lease_years                                                94
# remaining_lease_months                                              NaN
# resale_price                                                  265000.00
# price_per_sq_ft                                                  807.72
# price_per_sq_m                                                  2650.00
# price_per_sq_ft_per_lease_yr                                       8.59
# price_per_sq_m_per_lease_yr                                       28.19
# resale_price_norm                                             523740.16
# price_per_sq_ft_norm                                            1596.36
# price_per_sq_ft_per_lease_yr_norm                                 16.98
# price_per_sq_m_norm                                             5237.40
# price_per_sq_m_per_lease_yr_norm                                  55.72

# %% [markdown]
# <br>

# %% [markdown]
# *Timerange:*

# %%
df['month'] = pd.to_datetime(df['month']) 
df = df.sort_values(by='month', ascending=True).reset_index(drop=True)

# %%
def data_timeframe(df):
    print('\nNumber of rows of data: ............ ',len(df))  
    print('Most historic datapoint date: ...... ', df.month.iloc[0])
    print('Most recent datapoint date: ........ ', df.month.iloc[-1])
    print('Number of days of data: ............ ',(df.month.iloc[-1]-df.month.iloc[0])) 
    
data_timeframe(df)

# Number of rows of data: ............  867677
# Most historic datapoint date: ......  1990-01-01 00:00:00
# Most recent datapoint date: ........  2022-03-01 00:00:00
# Number of days of data: ............  11747 days 00:00:00
# Out:
# Number of rows of data: ............  867677
# Most historic datapoint date: ......  1990-01-01 00:00:00
# Most recent datapoint date: ........  2022-03-01 00:00:00
# Number of days of data: ............  11747 days 00:00:00

# %% [markdown]
# <br>

# %% [markdown]
# *Singapore specifics (data integrity check):*

# %%
planning_areas = pd.read_html('https://en.wikipedia.org/wiki/Planning_Areas_of_Singapore')[2]
planning_areas = planning_areas[['Name (English)', 'Region','Area (km²)', 'Population[7]', 'Density (/km²)']]
planning_areas.columns = ['Name', 'Region', 'Area_km2', 'Population', 'Density_per_km2']
planning_areas
# Out:
#                        Name      Region  Area_km2 Population Density_per_km2
# 0                Ang Mo Kio  North-East     13.94     163950           13400
# 1                     Bedok        East     21.69     279380           13000
# 2                    Bishan     Central      7.62      88010           12000
# 3                  Boon Lay        West      8.23         30             3.6
# 4               Bukit Batok        West     11.13     153740           14000
# 5               Bukit Merah     Central     14.34     151980           11000
# 6             Bukit Panjang        West      8.99     139280           15000
# 7               Bukit Timah     Central     17.53      77430            4400
# 8   Central Water Catchment       North     37.15          *               *
# 9                    Changi        East     40.61       1830           80.62
# 10               Changi Bay        East      1.70          *               *
# 11            Choa Chu Kang        West      6.11     190890           30000
# 12                 Clementi        West      9.49      92420            9800
# 13            Downtown Core     Central      4.34       2720             680
# 14                  Geylang     Central      9.64     110200           11400
# 15                  Hougang  North-East     13.93     226240           16000
# 16              Jurong East        West     17.83      79240            4400
# 17              Jurong West        West     14.69     264860           18000
# 18                  Kallang     Central      9.17     101520           11000
# 19             Lim Chu Kang       North     17.30        110             5.2
# 20                   Mandai       North     11.77       2090           180.2
# 21              Marina East     Central      1.82          *               *
# 22             Marina South     Central      1.62          *               *
# 23            Marine Parade     Central      6.12      46390            8000
# 24                   Museum     Central      0.83        420             480
# 25                   Newton     Central      2.07       8030            3800
# 26    North-Eastern Islands  North-East     42.88         50             1.2
# 27                   Novena     Central      8.98      49210            5600
# 28                  Orchard     Central      0.96        990           960.3
# 29                   Outram     Central      1.37      18960           13500
# 30                Pasir Ris        East     15.02     148020            9600
# 31               Paya Lebar        East     11.69         40             3.4
# 32                  Pioneer        West     12.10         90             8.3
# 33                  Punggol  North-East      9.34     170560           17800
# 34               Queenstown     Central     20.43      96340            4400
# 35             River Valley     Central      1.48      10250            6800
# 36                   Rochor     Central      1.62      13340            8300
# 37                  Seletar  North-East     10.25        250            26.3
# 38                Sembawang       North     12.34      95920            8400
# 39                 Sengkang  North-East     10.59     244600           23000
# 40                Serangoon  North-East     10.10     116310           11500
# 41                  Simpang       North      5.13          *               *
# 42          Singapore River     Central      0.96       3070            3000
# 43         Southern Islands     Central      6.07       1800             244
# 44             Straits View     Central      0.77          *               *
# 45             Sungei Kadut       North     15.99        780            53.2
# 46                 Tampines        East     20.89     256730           12400
# 47                  Tanglin     Central      7.63      21630            2800
# 48                   Tengah        West      7.40         10             1.4
# 49                Toa Payoh     Central      8.17     120650           14300
# 50                     Tuas        West     30.04         70             2.3
# 51          Western Islands        West     39.47         10            0.25
# 52  Western Water Catchment        West     69.46        720              13
# 53                Woodlands       North     13.59     254730           18700
# 54                   Yishun       North     21.24     220320           10100

# %%
# https://en.wikipedia.org/wiki/Regions_of_Singapore
regions = pd.read_html('https://en.wikipedia.org/wiki/Regions_of_Singapore')[1]
regions.columns = ['Region', 'Regional Centre', 'Largest PA by area', 'Largest PA by population', 'Area(km²)', 
                   'Estimated Population', 'Populationdensity(/km²)', 'PlanningAreas']
regions
# Out:
#               Region          Regional Centre       Largest PA by area  \
# 0     Central Region  Central Area (de facto)               Queenstown
# 1        East Region                 Tampines                   Changi
# 2       North Region                Woodlands  Central Water Catchment
# 3  North-East Region                  Seletar    North-Eastern Islands
# 4        West Region              Jurong East  Western Water Catchment
# 5              Total                      NaN                      NaN
#
#   Largest PA by population  Area(km²)  Estimated Population  \
# 0              Bukit Merah     132.70                922580
# 1                    Bedok      93.10                685890
# 2                Woodlands     134.50                582330
# 3                 Sengkang     103.90                930910
# 4              Jurong West     201.30                922540
# 5                      NaN     665.50               4044250
#
#    Populationdensity(/km²)  PlanningAreas
# 0                     6952             22
# 1                     7367              6
# 2                     4330              8
# 3                     8960              9
# 4                     4583             12
# 5                     6077             55

# %%
towns = pd.read_html('https://en.wikipedia.org/wiki/New_towns_of_Singapore')[0]

towns = towns[  ['Name (English/Malay)', 'Total area (km2)', 'Residential area (km2)', 
                 'Dwelling units', 'Projected ultimate', 'Population']]

towns.columns = ['Name', 'Total area (km2)', 'Residential area (km2)', 
                 'Dwelling units', 'Projected ultimate', 'Population']

towns
# Out:
#                Name  Total area (km2)  Residential area (km2)  Dwelling units  \
# 0        Ang Mo Kio              6.38                    2.83           50726
# 1             Bedok              9.37                    4.18           62816
# 2            Bishan              6.90                    1.72           20072
# 3       Bukit Batok              7.85                    2.91           44285
# 4       Bukit Merah              8.58                    3.12           54227
# 5     Bukit Panjang              4.89                    2.19           35325
# 6     Choa Chu Kang              5.83                    3.07           48900
# 7          Clementi              4.12                    2.03           26730
# 8           Geylang              6.78                    2.14           30892
# 9           Hougang             13.09                    3.67           57272
# 10      Jurong East              3.84                    1.65           24122
# 11      Jurong West              9.87                    4.80           75208
# 12  Kallang/Whampoa              7.99                    2.10           39931
# 13        Pasir Ris              6.01                    3.18           29654
# 14          Punggol              9.57                    3.74           50663
# 15       Queenstown              6.94                    2.10           33164
# 16        Sembawang              7.08                    3.31           30020
# 17         Sengkang             10.55                    3.97           69196
# 18        Serangoon              7.37                    1.63           21632
# 19         Tampines             12.00                    5.49           72683
# 20        Toa Payoh              5.56                    2.48           39737
# 21        Woodlands             11.98                    4.80           69900
# 22           Yishun              7.78                    3.98           65158
#
#     Projected ultimate  Population
# 0                58000      138200
# 1                79000      187900
# 2                34000       61100
# 3                54000      121400
# 4                68000      141400
# 5                44000      118900
# 6                62000      167200
# 7                39000       69500
# 8                50000       86000
# 9                72000      179700
# 10               31000       75400
# 11               94000      253800
# 12               57000      105200
# 13               44000      106600
# 14               96000      146900
# 15               60000       81200
# 16               65000       81500
# 17               96000      217700
# 18               30000       66800
# 19              110000      232700
# 20               61000      103800
# 21              102000      243300
# 22               84000      198500

# %%
estates = pd.read_html('https://en.wikipedia.org/wiki/New_towns_of_Singapore')[1]
estates = estates[['Name (English/Malay)', 'Dwelling units', 'Population']]
estates
# Out:
#   Name (English/Malay)  Dwelling units  Population
# 0          Bukit Timah            2423        8100
# 1        Marine Parade            6537       20800
# 2         Central Area            9459       27200

# %% [markdown]
# <br>

# %% [markdown]
# *Cleaning:*

# %%
# mapping towns to individual region is possible, can remove later if don't need

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sorted(regions.Region.unique()) 
# from scraped, as data integrity check !
# Out:
# ['Central Region',
#  'East Region',
#  'North Region',
#  'North-East Region',
#  'Total',
#  'West Region']

# %%
# mapping towns -> region 

town_to_region_mapper = pd.Series(planning_areas.Region.values,
                                  index=planning_areas.Name).to_dict()

town_to_region_mapper
# Out:
# {'Ang Mo Kio': 'North-East',
#  'Bedok': 'East',
#  'Bishan': 'Central',
#  'Boon Lay': 'West',
#  'Bukit Batok': 'West',
#  'Bukit Merah': 'Central',
#  'Bukit Panjang': 'West',
#  'Bukit Timah': 'Central',
#  'Central Water Catchment': 'North',
#  'Changi': 'East',
#  'Changi Bay': 'East',
#  'Choa Chu Kang': 'West',
#  'Clementi': 'West',
#  'Downtown Core': 'Central',
#  'Geylang': 'Central',
#  'Hougang': 'North-East',
#  'Jurong East': 'West',
#  'Jurong West': 'West',
#  'Kallang': 'Central',
#  'Lim Chu Kang': 'North',
#  'Mandai': 'North',
#  'Marina East': 'Central',
#  'Marina South': 'Central',
#  'Marine Parade': 'Central',
#  'Museum': 'Central',
#  'Newton': 'Central',
#  'North-Eastern Islands': 'North-East',
#  'Novena': 'Central',
#  'Orchard': 'Central',
#  'Outram': 'Central',
#  'Pasir Ris': 'East',
#  'Paya Lebar': 'East',
#  'Pioneer': 'West',
#  'Punggol': 'North-East',
#  'Queenstown': 'Central',
#  'River Valley': 'Central',
#  'Rochor': 'Central',
#  'Seletar': 'North-East',
#  'Sembawang': 'North',
#  'Sengkang': 'North-East',
#  'Serangoon': 'North-East',
#  'Simpang': 'North',
#  'Singapore River': 'Central',
#  'Southern Islands': 'Central',
#  'Straits View': 'Central',
#  'Sungei Kadut': 'North',
#  'Tampines': 'East',
#  'Tanglin': 'Central',
#  'Tengah': 'West',
#  'Toa Payoh': 'Central',
#  'Tuas': 'West',
#  'Western Islands': 'West',
#  'Western Water Catchment': 'West',
#  'Woodlands': 'North',
#  'Yishun': 'North'}

# %%
# already exists:  'Kallang': 'Central'
town_to_region_mapper['Central Area'] = 'Central'  # obviously
town_to_region_mapper['Kallang/Whampoa'] = 'Central'
# sometimes the Kallang/Whampoa are reversed in order...

# %%
town_to_region_mapper  # note, will be longer than our unique towns
# Out:
# {'Ang Mo Kio': 'North-East',
#  'Bedok': 'East',
#  'Bishan': 'Central',
#  'Boon Lay': 'West',
#  'Bukit Batok': 'West',
#  'Bukit Merah': 'Central',
#  'Bukit Panjang': 'West',
#  'Bukit Timah': 'Central',
#  'Central Water Catchment': 'North',
#  'Changi': 'East',
#  'Changi Bay': 'East',
#  'Choa Chu Kang': 'West',
#  'Clementi': 'West',
#  'Downtown Core': 'Central',
#  'Geylang': 'Central',
#  'Hougang': 'North-East',
#  'Jurong East': 'West',
#  'Jurong West': 'West',
#  'Kallang': 'Central',
#  'Lim Chu Kang': 'North',
#  'Mandai': 'North',
#  'Marina East': 'Central',
#  'Marina South': 'Central',
#  'Marine Parade': 'Central',
#  'Museum': 'Central',
#  'Newton': 'Central',
#  'North-Eastern Islands': 'North-East',
#  'Novena': 'Central',
#  'Orchard': 'Central',
#  'Outram': 'Central',
#  'Pasir Ris': 'East',
#  'Paya Lebar': 'East',
#  'Pioneer': 'West',
#  'Punggol': 'North-East',
#  'Queenstown': 'Central',
#  'River Valley': 'Central',
#  'Rochor': 'Central',
#  'Seletar': 'North-East',
#  'Sembawang': 'North',
#  'Sengkang': 'North-East',
#  'Serangoon': 'North-East',
#  'Simpang': 'North',
#  'Singapore River': 'Central',
#  'Southern Islands': 'Central',
#  'Straits View': 'Central',
#  'Sungei Kadut': 'North',
#  'Tampines': 'East',
#  'Tanglin': 'Central',
#  'Tengah': 'West',
#  'Toa Payoh': 'Central',
#  'Tuas': 'West',
#  'Western Islands': 'West',
#  'Western Water Catchment': 'West',
#  'Woodlands': 'North',
#  'Yishun': 'North',
#  'Central Area': 'Central',
#  'Kallang/Whampoa': 'Central'}

# %%
towns.Name   
# reference from previously scraped data, as quick reference
# Out:
# 0          Ang Mo Kio
# 1               Bedok
# 2              Bishan
# 3         Bukit Batok
# 4         Bukit Merah
# 5       Bukit Panjang
# 6       Choa Chu Kang
# 7            Clementi
# 8             Geylang
# 9             Hougang
# 10        Jurong East
# 11        Jurong West
# 12    Kallang/Whampoa
# 13          Pasir Ris
# 14            Punggol
# 15         Queenstown
# 16          Sembawang
# 17           Sengkang
# 18          Serangoon
# 19           Tampines
# 20          Toa Payoh
# 21          Woodlands
# 22             Yishun
# Name: Name, dtype: object

# %%
df['town'] = df['town'].str.title() 
# df['town'] = df['town'].str.replace('/','_')

# %%
sorted(df.town.unique().tolist())  
# len(df.town.unique()) - >  27 unique towns
# Out:
# ['Ang Mo Kio',
#  'Bedok',
#  'Bishan',
#  'Bukit Batok',
#  'Bukit Merah',
#  'Bukit Panjang',
#  'Bukit Timah',
#  'Central Area',
#  'Choa Chu Kang',
#  'Clementi',
#  'Geylang',
#  'Hougang',
#  'Jurong East',
#  'Jurong West',
#  'Kallang/Whampoa',
#  'Lim Chu Kang',
#  'Marine Parade',
#  'Pasir Ris',
#  'Punggol',
#  'Queenstown',
#  'Sembawang',
#  'Sengkang',
#  'Serangoon',
#  'Tampines',
#  'Toa Payoh',
#  'Woodlands',
#  'Yishun']

# %%
# create new feature `region`:

df['region']= df['town'].map(town_to_region_mapper)

# had to fix for two missed towns:
# df.region.isnull().sum()    31991
# find the null values for towns -> region mapping we missed...

# df[df['region'].isnull()].town.unique()
#   array(['Kallang/Whampoa', 'Central Area'], dtype=object)

# https://en.wikipedia.org/wiki/Central_Area,_Singapore#:~:text=Located%20in%20the%20south%2Deastern,defined%20by%20the%20Urban%20Redevelopment

# %%
df.region.isnull().sum()  # 0, so no missed town -> region mapping
# Out:
# 0

# %%
quick_vc_bar('region')
# Out:
# Value Counts Histogram: region

# %% [markdown]
# > Somewhat even distribution between regions...

# %%
df.columns
# Out:
# Index(['transaction_id', 'month', 'block', 'town', 'street_name', 'address',
#        'storey_range', 'storey_range_min', 'storey_range_max', 'flat_model',
#        'flat_type', 'n_rooms', 'floor_area_sqm', 'lease_commence_date',
#        'remaining_lease', 'remaining_lease_years', 'remaining_lease_months',
#        'resale_price', 'price_per_sq_ft', 'price_per_sq_m',
#        'price_per_sq_ft_per_lease_yr', 'price_per_sq_m_per_lease_yr',
#        'resale_price_norm', 'price_per_sq_ft_norm',
#        'price_per_sq_ft_per_lease_yr_norm', 'price_per_sq_m_norm',
#        'price_per_sq_m_per_lease_yr_norm', 'region'],
#       dtype='object')

# %% [markdown]
# <br>

# %%
df['flat_type'] = df['flat_type'].str.title()

# %%
df.flat_type.unique().tolist() 
# 'Multi Generation' is the same as 'Multi-Generation' ?  i think so. 
# Need to figure out if 'Executive' is a suite, or is possible convert to 'floor' equivalent
# Out:
# ['5 Room',
#  '3 Room',
#  'Executive',
#  '4 Room',
#  '2 Room',
#  '1 Room',
#  'Multi Generation',
#  'Multi-Generation']

# %%
df.flat_type.value_counts()
# Out:
# 4 Room              326642
# 3 Room              281537
# 5 Room              181388
# Executive            65876
# 2 Room               10421
# 1 Room                1285
# Multi Generation       279
# Multi-Generation       249
# Name: flat_type, dtype: int64

# %%
df['flat_type'] = df['flat_type'].str.replace('Multi-Generation', 'Multi Generation', 
                                              regex=True)

# %%
df.flat_type.unique().tolist()
# Out:
# ['5 Room',
#  '3 Room',
#  'Executive',
#  '4 Room',
#  '2 Room',
#  '1 Room',
#  'Multi Generation']

# %%
# link to explanation of flat types:
# https://sg.finance.yahoo.com/news/different-types-hdb-houses-call-020000642.html
# worth seeing if can modify forms

# %%
df.flat_type.value_counts()
# Out:
# 4 Room              326060
# 3 Room              280629
# 5 Room              181149
# Executive            65819
# 2 Room               10375
# 1 Room                1254
# Multi Generation       528
# Name: flat_type, dtype: int64

# %%
df.flat_type.value_counts(normalize=True)
# Out:
# 4 Room             0.38
# 3 Room             0.32
# 5 Room             0.21
# Executive          0.08
# 2 Room             0.01
# 1 Room             0.00
# Multi Generation   0.00
# Name: flat_type, dtype: float64

# %%
#  **WARNING**:  this means that
#  Executive            65876
#  Multi Generation       528
#  won't have n_room count... which means that feature is odd...

# %% [markdown]
# <br>

# %%
df.n_rooms.value_counts() 
# are there any NaNs ???
# i dont like this:  room count isn't mapped for some flat_types...
# watch missing values here...
# Out:
# 4    326642
# 3    281537
# 5    247792
# 2     10421
# 1      1285
# Name: n_rooms, dtype: int64

# %%
df.n_rooms.value_counts(normalize=True)
# Out:
# 4   0.38
# 3   0.32
# 5   0.29
# 2   0.01
# 1   0.00
# Name: n_rooms, dtype: float64

# %%
df.n_rooms.isnull().sum()
# Out:
# 0

# %% [markdown]
# <br>

# %%
df.storey_range.unique().tolist()
# Out:
# ['07 TO 09',
#  '13 TO 15',
#  '10 TO 12',
#  '04 TO 06',
#  '01 TO 03',
#  '16 TO 18',
#  '19 TO 21',
#  '22 TO 24',
#  '25 TO 27',
#  '28 TO 30',
#  '31 TO 33',
#  '37 TO 39',
#  '40 TO 42',
#  '34 TO 36',
#  '11 TO 15',
#  '06 TO 10',
#  '01 TO 05',
#  '16 TO 20',
#  '26 TO 30',
#  '21 TO 25',
#  '36 TO 40',
#  '31 TO 35',
#  '46 TO 48',
#  '43 TO 45',
#  '49 TO 51']

# %%
df.storey_range.value_counts()  
# note:  these are categories technically
# Out:
# 04 TO 06    219080
# 07 TO 09    197527
# 01 TO 03    176124
# 10 TO 12    167727
# 13 TO 15     56326
# 16 TO 18     21490
# 19 TO 21     10245
# 22 TO 24      6660
# 25 TO 27      2905
# 01 TO 05      2700
# 06 TO 10      2474
# 28 TO 30      1277
# 11 TO 15      1259
# 31 TO 33       423
# 34 TO 36       392
# 37 TO 39       379
# 16 TO 20       265
# 40 TO 42       191
# 21 TO 25        92
# 43 TO 45        43
# 26 TO 30        39
# 46 TO 48        37
# 49 TO 51        13
# 36 TO 40         7
# 31 TO 35         2
# Name: storey_range, dtype: int64

# %%
df.storey_range.value_counts(normalize=True)  
# high imbalance...
# Out:
# 04 TO 06   0.25
# 07 TO 09   0.23
# 01 TO 03   0.20
# 10 TO 12   0.19
# 13 TO 15   0.06
# 16 TO 18   0.02
# 19 TO 21   0.01
# 22 TO 24   0.01
# 25 TO 27   0.00
# 01 TO 05   0.00
# 06 TO 10   0.00
# 28 TO 30   0.00
# 11 TO 15   0.00
# 31 TO 33   0.00
# 34 TO 36   0.00
# 37 TO 39   0.00
# 16 TO 20   0.00
# 40 TO 42   0.00
# 21 TO 25   0.00
# 43 TO 45   0.00
# 26 TO 30   0.00
# 46 TO 48   0.00
# 49 TO 51   0.00
# 36 TO 40   0.00
# 31 TO 35   0.00
# Name: storey_range, dtype: float64

# %% [markdown]
# > high imbalance in flats to storey ranges

# %%
# adding new feature
df['storey_range_avg'] = (df['storey_range_min'] + df['storey_range_max'])/2
df['storey_range_avg'] = df['storey_range_avg']

# %%
sorted(list(df.columns))
# Out:
# ['address',
#  'block',
#  'flat_model',
#  'flat_type',
#  'floor_area_sqm',
#  'lease_commence_date',
#  'month',
#  'n_rooms',
#  'price_per_sq_ft',
#  'price_per_sq_ft_norm',
#  'price_per_sq_ft_per_lease_yr',
#  'price_per_sq_ft_per_lease_yr_norm',
#  'price_per_sq_m',
#  'price_per_sq_m_norm',
#  'price_per_sq_m_per_lease_yr',
#  'price_per_sq_m_per_lease_yr_norm',
#  'region',
#  'remaining_lease',
#  'remaining_lease_months',
#  'remaining_lease_years',
#  'resale_price',
#  'resale_price_norm',
#  'storey_range',
#  'storey_range_avg',
#  'storey_range_max',
#  'storey_range_min',
#  'street_name',
#  'town',
#  'transaction_id']

# %% [markdown]
# <br>

# %%
df['flat_model'] = df['flat_model'].str.lower()
df['flat_model'] = df['flat_model'].str.title()

# %%
sorted(df.flat_model.unique().tolist())
# we must assume these have many duplicated...
# i.e. IMPROVED actually equals Improved

# i dont like this. i feel like some of these apt types are 
# potentially subsets of other types of flat_models...
# consolidate somehow ?
# Out:
# ['2-Room',
#  'Adjoined Flat',
#  'Apartment',
#  'Dbss',
#  'Improved',
#  'Improved-Maisonette',
#  'Maisonette',
#  'Model A',
#  'Model A-Maisonette',
#  'Model A2',
#  'Multi Generation',
#  'New Generation',
#  'Premium Apartment',
#  'Premium Apartment Loft',
#  'Premium Maisonette',
#  'Simplified',
#  'Standard',
#  'Terrace',
#  'Type S1',
#  'Type S2']

# %%
df.flat_model.value_counts()
# Out:
# Model A                   242085
# Improved                  227608
# New Generation            182187
# Simplified                 55343
# Standard                   41043
# Premium Apartment          40331
# Apartment                  33602
# Maisonette                 28187
# Model A2                    9486
# Dbss                        2595
# Model A-Maisonette          1974
# Adjoined Flat               1155
# Terrace                      670
# Multi Generation             528
# Type S1                      359
# Type S2                      185
# Improved-Maisonette          118
# Premium Maisonette            85
# Premium Apartment Loft        83
# 2-Room                        53
# Name: flat_model, dtype: int64

# %%
df.flat_model.value_counts(normalize=True)
# Out:
# Model A                  0.28
# Improved                 0.26
# New Generation           0.21
# Simplified               0.06
# Standard                 0.05
# Premium Apartment        0.05
# Apartment                0.04
# Maisonette               0.03
# Model A2                 0.01
# Dbss                     0.00
# Model A-Maisonette       0.00
# Adjoined Flat            0.00
# Terrace                  0.00
# Multi Generation         0.00
# Type S1                  0.00
# Type S2                  0.00
# Improved-Maisonette      0.00
# Premium Maisonette       0.00
# Premium Apartment Loft   0.00
# 2-Room                   0.00
# Name: flat_model, dtype: float64

# %% [markdown]
# <br>

# %%
sorted(list(df.lease_commence_date.unique()))
# Out:
# [1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019]

# %%
df.lease_commence_date.value_counts()
# Out:
# 1985    84250
# 1984    61028
# 1988    48692
# 1987    41174
# 1978    39823
# 1986    37124
# 1989    30940
# 1980    30914
# 1979    29815
# 1997    29361
# 1993    26987
# 1996    26778
# 1998    24182
# 1983    22233
# 1976    20673
# 1981    20105
# 1977    19975
# 1999    19391
# 1992    19334
# 1995    18135
# 2001    17833
# 2000    16998
# 1975    16703
# 2003    14280
# 1974    14022
# 1982    12800
# 2002    11464
# 1970    10981
# 1990     8915
# 1973     8302
# 1969     8090
# 2004     7703
# 1971     7626
# 2015     7613
# 1994     6227
# 1967     5939
# 1972     5585
# 2016     4434
# 2013     4314
# 2012     4010
# 2005     3614
# 2014     2826
# 2006     2813
# 2017     2632
# 2011     2235
# 2008     1862
# 1968     1822
# 2009     1555
# 1991     1192
# 2010     1159
# 2007      836
# 2018      315
# 2019       33
# 1966       30
# Name: lease_commence_date, dtype: int64

# %%
df.lease_commence_date.value_counts().sort_index(ascending=False)
# Out:
# 2019       33
# 2018      315
# 2017     2632
# 2016     4434
# 2015     7613
# 2014     2826
# 2013     4314
# 2012     4010
# 2011     2235
# 2010     1159
# 2009     1555
# 2008     1862
# 2007      836
# 2006     2813
# 2005     3614
# 2004     7703
# 2003    14280
# 2002    11464
# 2001    17833
# 2000    16998
# 1999    19391
# 1998    24182
# 1997    29361
# 1996    26778
# 1995    18135
# 1994     6227
# 1993    26987
# 1992    19334
# 1991     1192
# 1990     8915
# 1989    30940
# 1988    48692
# 1987    41174
# 1986    37124
# 1985    84250
# 1984    61028
# 1983    22233
# 1982    12800
# 1981    20105
# 1980    30914
# 1979    29815
# 1978    39823
# 1977    19975
# 1976    20673
# 1975    16703
# 1974    14022
# 1973     8302
# 1972     5585
# 1971     7626
# 1970    10981
# 1969     8090
# 1968     1822
# 1967     5939
# 1966       30
# Name: lease_commence_date, dtype: int64

# %% [markdown]
# <br>

# %% [markdown]
# *Drop Duplicate Rows (initial):*

# %%
df = df.drop_duplicates() # keep=False, inplace=True

# %%
len(df)
# Out:
# 865814

# %%
original_number_of_observations
# Out:
# 867677

# %%
original_number_of_observations - len(df)
# Out:
# 1863

# %%
sorted(df.columns.to_list())
# Out:
# ['address',
#  'block',
#  'flat_model',
#  'flat_type',
#  'floor_area_sqm',
#  'lease_commence_date',
#  'month',
#  'n_rooms',
#  'price_per_sq_ft',
#  'price_per_sq_ft_norm',
#  'price_per_sq_ft_per_lease_yr',
#  'price_per_sq_ft_per_lease_yr_norm',
#  'price_per_sq_m',
#  'price_per_sq_m_norm',
#  'price_per_sq_m_per_lease_yr',
#  'price_per_sq_m_per_lease_yr_norm',
#  'region',
#  'remaining_lease',
#  'remaining_lease_months',
#  'remaining_lease_years',
#  'resale_price',
#  'resale_price_norm',
#  'storey_range',
#  'storey_range_avg',
#  'storey_range_max',
#  'storey_range_min',
#  'street_name',
#  'town',
#  'transaction_id']

# %% [markdown]
# <br>

# %% [markdown]
# *How many observations/datapoints by 'month':*

# %%
sns.displot(df['month'],color='navy', alpha=0.6);

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <br>

# %%
len(df[df.duplicated(['transaction_id'])])
# Out:
# 57160

# %% [markdown]
# <br>

# %% [markdown]
# *Pandas Profiling:*

# %%
# commenting out, already ran for clarity ...
# 
#  profile = ProfileReport(df, title="Pandas Profiling Report - Base Dataset")
#  profile.to_notebook_iframe()
#   takes up a fair amount of time, but helpful 
#   takes about: 3 minutes and 29.81 seconds to run

# %% [markdown]
# <br>

# %%
df.town.value_counts()
# Out:
# Tampines           75994
# Yishun             65660
# Bedok              63493
# Jurong West        62727
# Woodlands          60870
# Ang Mo Kio         49620
# Hougang            47521
# Bukit Batok        41462
# Choa Chu Kang      35458
# Bukit Merah        32066
# Pasir Ris          31579
# Toa Payoh          29687
# Sengkang           27739
# Queenstown         27215
# Geylang            26681
# Clementi           26678
# Bukit Panjang      25751
# Kallang/Whampoa    25221
# Jurong East        23624
# Serangoon          21847
# Bishan             20339
# Punggol            16050
# Sembawang          11728
# Marine Parade       7650
# Central Area        6698
# Bukit Timah         2393
# Lim Chu Kang          63
# Name: town, dtype: int64

# %%
quick_vc_bar('town')
# Out:
# Value Counts Histogram: town

# %% [markdown]
# > There are four towns that have somewhat low observations

# %%
df.storey_range.value_counts()
# Out:
# 04 TO 06    218530
# 07 TO 09    197105
# 01 TO 03    175819
# 10 TO 12    167353
# 13 TO 15     56211
# 16 TO 18     21443
# 19 TO 21     10217
# 22 TO 24      6650
# 25 TO 27      2900
# 01 TO 05      2696
# 06 TO 10      2472
# 28 TO 30      1277
# 11 TO 15      1259
# 31 TO 33       423
# 34 TO 36       391
# 37 TO 39       379
# 16 TO 20       265
# 40 TO 42       191
# 21 TO 25        92
# 43 TO 45        43
# 26 TO 30        39
# 46 TO 48        37
# 49 TO 51        13
# 36 TO 40         7
# 31 TO 35         2
# Name: storey_range, dtype: int64

# %%
plt.figure(figsize=(10,6))
quick_vc_bar('storey_range');
# Out:
# Value Counts Histogram: storey_range

# %% [markdown]
# > There are four storey ranges that seem to encompass the vast majority...

# %% [markdown]
# <br>

# %% [markdown]
# *High-Level EDA:*

# %%
display(df.describe())
# Out:
#        storey_range_min  storey_range_max   n_rooms  floor_area_sqm  \
# count         865814.00         865814.00 865814.00       865814.00
# mean               6.60              8.62      3.93           95.71
# std                4.72              4.72      0.82           25.96
# min                1.00              3.00      1.00           28.00
# 25%                4.00              6.00      3.00           73.00
# 50%                7.00              9.00      4.00           93.00
# 75%               10.00             12.00      5.00          113.00
# max               49.00             51.00      5.00          307.00
#
#        lease_commence_date  remaining_lease_years  remaining_lease_months  \
# count            865814.00              865814.00               158351.00
# mean               1987.63                  81.00                    4.24
# std                   9.97                  10.18                    3.83
# min                1966.00                  43.00                    0.00
# 25%                1980.00                  74.00                    0.00
# 50%                1986.00                  83.00                    4.00
# 75%                1995.00                  89.00                    8.00
# max                2019.00                 101.00                   11.00
#
#        resale_price  price_per_sq_ft  price_per_sq_m  \
# count     865814.00        865814.00       865814.00
# mean      303798.94           955.04         3133.33
# std       156210.92           413.97         1358.18
# min         5000.00            49.16          161.29
# 25%       186000.00           687.42         2255.32
# 50%       283000.00           867.14         2844.96
# 75%       395000.00          1198.49         3932.04
# max      1360000.00          3932.90        12903.23
#
#        price_per_sq_ft_per_lease_yr  price_per_sq_m_per_lease_yr  \
# count                     865814.00                    865814.00
# mean                          12.23                        40.13
# std                            6.17                        20.25
# min                            0.59                         1.94
# 25%                            8.18                        26.84
# 50%                           10.47                        34.34
# 75%                           15.43                        50.63
# max                           65.63                       215.31
#
#        resale_price_norm  price_per_sq_ft_norm  \
# count          865814.00             865814.00
# mean           489577.55               1536.88
# std            192127.34                337.55
# min             24587.76                241.75
# 25%            345125.00               1320.89
# 50%            460032.15               1487.48
# 75%            584088.05               1692.16
# max           1792857.14               4441.42
#
#        price_per_sq_ft_per_lease_yr_norm  price_per_sq_m_norm  \
# count                          865814.00            865814.00
# mean                               19.27              5042.25
# std                                 4.89              1107.46
# min                                 2.95               793.15
# 25%                                15.97              4333.62
# 50%                                18.26              4880.20
# 75%                                21.60              5551.72
# max                                74.17             14571.59
#
#        price_per_sq_m_per_lease_yr_norm  storey_range_avg
# count                         865814.00         865814.00
# mean                              63.23              7.61
# std                               16.05              4.72
# min                                9.67              2.00
# 25%                               52.39              5.00
# 50%                               59.92              8.00
# 75%                               70.88             11.00
# max                              243.34             50.00

# %%
# a clearer representation 
df.describe().transpose()
# Out:
#                                       count      mean       std      min  \
# storey_range_min                  865814.00      6.60      4.72     1.00
# storey_range_max                  865814.00      8.62      4.72     3.00
# n_rooms                           865814.00      3.93      0.82     1.00
# floor_area_sqm                    865814.00     95.71     25.96    28.00
# lease_commence_date               865814.00   1987.63      9.97  1966.00
# remaining_lease_years             865814.00     81.00     10.18    43.00
# remaining_lease_months            158351.00      4.24      3.83     0.00
# resale_price                      865814.00 303798.94 156210.92  5000.00
# price_per_sq_ft                   865814.00    955.04    413.97    49.16
# price_per_sq_m                    865814.00   3133.33   1358.18   161.29
# price_per_sq_ft_per_lease_yr      865814.00     12.23      6.17     0.59
# price_per_sq_m_per_lease_yr       865814.00     40.13     20.25     1.94
# resale_price_norm                 865814.00 489577.55 192127.34 24587.76
# price_per_sq_ft_norm              865814.00   1536.88    337.55   241.75
# price_per_sq_ft_per_lease_yr_norm 865814.00     19.27      4.89     2.95
# price_per_sq_m_norm               865814.00   5042.25   1107.46   793.15
# price_per_sq_m_per_lease_yr_norm  865814.00     63.23     16.05     9.67
# storey_range_avg                  865814.00      7.61      4.72     2.00
#
#                                         25%       50%       75%        max
# storey_range_min                       4.00      7.00     10.00      49.00
# storey_range_max                       6.00      9.00     12.00      51.00
# n_rooms                                3.00      4.00      5.00       5.00
# floor_area_sqm                        73.00     93.00    113.00     307.00
# lease_commence_date                 1980.00   1986.00   1995.00    2019.00
# remaining_lease_years                 74.00     83.00     89.00     101.00
# remaining_lease_months                 0.00      4.00      8.00      11.00
# resale_price                      186000.00 283000.00 395000.00 1360000.00
# price_per_sq_ft                      687.42    867.14   1198.49    3932.90
# price_per_sq_m                      2255.32   2844.96   3932.04   12903.23
# price_per_sq_ft_per_lease_yr           8.18     10.47     15.43      65.63
# price_per_sq_m_per_lease_yr           26.84     34.34     50.63     215.31
# resale_price_norm                 345125.00 460032.15 584088.05 1792857.14
# price_per_sq_ft_norm                1320.89   1487.48   1692.16    4441.42
# price_per_sq_ft_per_lease_yr_norm     15.97     18.26     21.60      74.17
# price_per_sq_m_norm                 4333.62   4880.20   5551.72   14571.59
# price_per_sq_m_per_lease_yr_norm      52.39     59.92     70.88     243.34
# storey_range_avg                       5.00      8.00     11.00      50.00

# %%
fig = plt.figure(figsize=(9,7))
fig.suptitle('HDB Resale Prices (Mean)', fontsize=13)
ax1 = fig.add_subplot(211)
df.groupby('month')[['resale_price']].median().plot(ax=ax1, 
                                                    color='navy', 
                                                    alpha=0.6,
                                                    legend=None)
ax1.set_ylabel('Resale Price')
ax1.set_title('Original Data Pricing', size=12)
ax2 = fig.add_subplot(212)
df.groupby('month')[['resale_price_norm']].median().plot(ax=ax2, 
                                                         color='maroon', 
                                                         alpha=0.6,
                                                         legend=None)
ax2.set_ylabel('Resale Price')
ax2.set_title('Normalized Resale Price', size=12)
plt.tight_layout(rect=[0.05, 0.05, 0.95, 0.95]) 
plt.show();

# %%
fig = plt.figure(figsize=(9,7))
fig.suptitle('HDB Resale Prices (Average)', fontsize=13)
ax1 = fig.add_subplot(211)
df.groupby('month')[['resale_price']].mean().plot(ax=ax1, 
                                                    color='navy', 
                                                    alpha=0.6,
                                                    legend=None)
ax1.set_ylabel('Resale Price')
ax1.set_title('Original Data Pricing', size=12)
ax2 = fig.add_subplot(212)
df.groupby('month')[['resale_price_norm']].mean().plot(ax=ax2, 
                                                         color='maroon', 
                                                         alpha=0.6,
                                                         legend=None)
ax2.set_ylabel('Resale Price')
ax2.set_title('Normalized Resale Price', size=12)
plt.tight_layout(rect=[0.05, 0.05, 0.95, 0.95]) 
plt.show();

# %%
price = df['resale_price_norm'].nunique()
fig = plt.figure(figsize=(12,8))
plt.hist(df['resale_price'], 
         bins = 100, 
         color='navy', 
         alpha=0.6)
sns.despine()
plt.ylabel('Counts', fontsize=12)
plt.xlabel('\nResale Price (norm)', fontsize=11)
plt.xticks(rotation='vertical')
plt.title("\nResale Price Histogram\n", fontsize=13)
plt.show();

# %% [markdown]
# > This is left skewed, may make sense to do log transform later

# %% [markdown]
# <br>

# %%
display(df.describe())
# Out:
#        storey_range_min  storey_range_max   n_rooms  floor_area_sqm  \
# count         865814.00         865814.00 865814.00       865814.00
# mean               6.60              8.62      3.93           95.71
# std                4.72              4.72      0.82           25.96
# min                1.00              3.00      1.00           28.00
# 25%                4.00              6.00      3.00           73.00
# 50%                7.00              9.00      4.00           93.00
# 75%               10.00             12.00      5.00          113.00
# max               49.00             51.00      5.00          307.00
#
#        lease_commence_date  remaining_lease_years  remaining_lease_months  \
# count            865814.00              865814.00               158351.00
# mean               1987.63                  81.00                    4.24
# std                   9.97                  10.18                    3.83
# min                1966.00                  43.00                    0.00
# 25%                1980.00                  74.00                    0.00
# 50%                1986.00                  83.00                    4.00
# 75%                1995.00                  89.00                    8.00
# max                2019.00                 101.00                   11.00
#
#        resale_price  price_per_sq_ft  price_per_sq_m  \
# count     865814.00        865814.00       865814.00
# mean      303798.94           955.04         3133.33
# std       156210.92           413.97         1358.18
# min         5000.00            49.16          161.29
# 25%       186000.00           687.42         2255.32
# 50%       283000.00           867.14         2844.96
# 75%       395000.00          1198.49         3932.04
# max      1360000.00          3932.90        12903.23
#
#        price_per_sq_ft_per_lease_yr  price_per_sq_m_per_lease_yr  \
# count                     865814.00                    865814.00
# mean                          12.23                        40.13
# std                            6.17                        20.25
# min                            0.59                         1.94
# 25%                            8.18                        26.84
# 50%                           10.47                        34.34
# 75%                           15.43                        50.63
# max                           65.63                       215.31
#
#        resale_price_norm  price_per_sq_ft_norm  \
# count          865814.00             865814.00
# mean           489577.55               1536.88
# std            192127.34                337.55
# min             24587.76                241.75
# 25%            345125.00               1320.89
# 50%            460032.15               1487.48
# 75%            584088.05               1692.16
# max           1792857.14               4441.42
#
#        price_per_sq_ft_per_lease_yr_norm  price_per_sq_m_norm  \
# count                          865814.00            865814.00
# mean                               19.27              5042.25
# std                                 4.89              1107.46
# min                                 2.95               793.15
# 25%                                15.97              4333.62
# 50%                                18.26              4880.20
# 75%                                21.60              5551.72
# max                                74.17             14571.59
#
#        price_per_sq_m_per_lease_yr_norm  storey_range_avg
# count                         865814.00         865814.00
# mean                              63.23              7.61
# std                               16.05              4.72
# min                                9.67              2.00
# 25%                               52.39              5.00
# 50%                               59.92              8.00
# 75%                               70.88             11.00
# max                              243.34             50.00

# %%
flat_type = np.unique(df['flat_type'])
n = len(flat_type)
avg_price = np.zeros(n)
for i in range(0,n):
        price = df['resale_price_norm'][df['flat_type'] == flat_type[i]].sum()
        sqm = df['floor_area_sqm'][df['flat_type'] == flat_type[i]].sum()
        price_f = price/sqm
        avg_price[i] = price_f
sns.barplot(flat_type,avg_price, color='navy', alpha=0.6)
plt.ylabel('Avg price/sqm', fontsize=12)
plt.xlabel('Flat Type', fontsize=12)
plt.xticks(rotation='vertical')
plt.title("Avg price/sqm", fontsize=12)
plt.show();

# %%
flat_model = np.unique(df['flat_model'])
n = len(flat_model)
avg_price = np.zeros(n)
for i in range(0,n):
        price = df['resale_price'][df['flat_model'] == flat_model[i]].sum()
        sq_m = df['floor_area_sqm'][df['flat_model'] == flat_model[i]].sum()
        price_f= price/sq_m
        avg_price[i] = price_f
sns.barplot(flat_model,avg_price, color='navy', alpha=0.6)
plt.ylabel('Avg price/sqm', fontsize=12)
plt.xlabel('Flat Model', fontsize=12)
plt.xticks(rotation='vertical')
plt.title("Avg price/sqm", fontsize=12)
plt.show();

# %%
quick_vc_bar('storey_range');
# Out:
# Value Counts Histogram: storey_range

# %%
storey_array = np.unique(df['storey_range'])
n = len(storey_array)
avg_price = np.zeros(n)
for i in range(0,n):
        price = df['resale_price'][df['storey_range'] == storey_array[i]].sum()
        sqm = df['floor_area_sqm'][df['storey_range'] == storey_array[i]].sum()
        price_f = price/sqm
        avg_price[i] = price_f
plt.figure(figsize=(9,6))
sns.barplot(storey_array,
            avg_price, color='navy', 
            alpha=0.6)
plt.ylabel('Avg Price per sqm\n', 
           fontsize=10)
plt.xlabel('\nStoreys', fontsize=10)
plt.xticks(rotation='vertical')
plt.title("Avg price per sqm",fontsize=12)
sns.despine()
plt.show();

# %% [markdown]
# <br>

# %%
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(8.5,5.5))
sns.distplot(df['floor_area_sqm'], 
             kde=False, 
             color='navy',
             kde_kws={'bw':4, "linewidth":.9, 'alpha':.6},
             hist_kws={"linewidth": .10, 'edgecolor':'black', 'alpha':.6, "rwidth":0.75},
             bins=35)    
sns.despine(top=True, right=True, left=True, bottom=True)
ax.xaxis.set_major_locator(plt.MultipleLocator(10))
# ax.set_yticklabels([])
plt.title('\nDistribution of Singapore HDB Floor Area (sqm)',fontsize=12, loc="center")
ax.set(xlabel="\nSquare Meter Area of Flat (sqm)\n")
plt.grid(linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show();

# %% [markdown]
# <br>

# %%
# Visualizing regression models
fig = plt.figure(figsize=(14,7))
p=sns.regplot(x='floor_area_sqm', 
              y='resale_price_norm', 
              data=df, 
              color='navy',
              scatter_kws={"s": .8, 'alpha':0.6})
sns.despine()
p.set_ylabel('Resale Price Norm', size=11)
p.set_xlabel('Floorspace - sqare meters', size=11)
plt.show();

# %% [markdown]
# <br>

# %%
fig = plt.figure(figsize=(14,6))
p=sns.regplot(x='remaining_lease_years', 
              y='resale_price_norm', 
              data=df, 
              color='maroon',
              scatter_kws={"s": .8, 'alpha':0.6})
p.set_ylabel('Resale Price Norm', size=11)
p.set_xlabel('Lease Remaining Years', size=11)
plt.show();

# %%
sns.lmplot(x="floor_area_sqm",
           y="resale_price_norm", 
           hue="storey_range", 
           data=df);

# %%
plt.figure(figsize=(14,6))
sns.lmplot(x="floor_area_sqm",
           y="resale_price_norm", 
           hue="n_rooms",
           scatter_kws={"s": .8, 'alpha':0.6},
           data=df)
sns.despine()
plt.show();

# %%
fig = plt.figure(figsize=(16,8))
p=sns.boxplot(x='flat_model', 
              y='resale_price_norm', 
              data=df, 
              width=0.7,
              color='lightblue',
              order=df.groupby('flat_model')['resale_price_norm'].mean().sort_values().reset_index()['flat_model'].tolist())
p.set_xticklabels(p.get_xticklabels(),
                  rotation=35, 
                  ha='right')
sns.despine()
p.set_xlabel('Flat_Model', size=11)
ylabels = ['{:,.0f}'.format(x) + 'K' for x in p.get_yticks()/1000]
p.set_yticklabels(ylabels)
p.set_ylabel('Resale Price Norm', size=12)
plt.show();
# Out:
# FixedFormatter should only be used together with FixedLocator

# %%
# sns.set_style("ticks", {'grid.linestyle': '--'})
flierprops = dict(markerfacecolor='0.2', 
                  markersize=1,
                  linestyle='none')
fig, ax = plt.subplots(figsize=(12,10))
ax.set_title('\nResale Price (norm) vs flat model type\n', fontsize=12, loc='center')
sns.boxplot(x=df['resale_price_norm'].sort_values(ascending=False),
            y=df['flat_model'],
            ax=ax,
            showfliers=False,
            linewidth=.8)
ax.yaxis.grid(False)   # Show the horizontal gridlines
ax.xaxis.grid(True)  # Hide x-axis gridlines 
# ax.xaxis.set_major_locator(plt.MultipleLocator(5))
# ax.yaxis.set_minor_locator(plt.MultipleLocator(5))
for patch in ax.artists:
  r, g, b, a = patch.get_facecolor()
  patch.set_facecolor((r, g, b, .3))
# ax.set(xlabel=''common xlabel', ylabel='common ylabel', title='some title')
ax.set(xlabel="\nFlat Model Normalized Price (M S$\n")
sns.despine(top=True, right=True, left=True, bottom=True)
ax.xaxis.set_ticks_position('none') 
ax.set_ylabel('')
ax.grid(linestyle='--', 
        linewidth='0.3', 
        color='lightgray', 
        alpha=0.8,
        axis='x'
       )
# plt.axvline(0, 0,1, linewidth=.4, color="blue", linestyle="--")
plt.tight_layout()
plt.show();
# outliers removed for clarity

# %%
plt.figure(figsize=(12,8))
sns.distplot(df.floor_area_sqm, color='navy')
sns.despine()
plt.title("\nSquare Meter Floor Area\n", fontsize=13)
plt.show();

# %%
plt.figure(figsize=(11,5))
sales_year = np.unique(pd.DatetimeIndex(df['month']).year.values)
n = len(sales_year)
avg_price = np.zeros(n)
for i in range(0,n):
        price = df['resale_price_norm'][pd.DatetimeIndex(df['month']).year == sales_year[i]].sum()
        sqmm = df['floor_area_sqm'][pd.DatetimeIndex(df['month']).year == sales_year[i]].sum()
        price_f= price/sqmm
        avg_price[i] = price_f
sns.barplot(sales_year, avg_price, color='navy', alpha=0.6)
plt.ylabel('Avg price/sqm (norm)', fontsize=11)
plt.xlabel('\nYear', fontsize=11)
plt.title("Avg price/sqm", fontsize=12)
plt.xticks(rotation='vertical')
sns.despine()
plt.show();

# %% [markdown]
# > Note:  This is adjusted (normalized)

# %% [markdown]
# <br>

# %% [markdown]
# *Correlation Plots:*

# %%
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['savefig.facecolor']='white'

plt.figure(figsize=(12,12))
sns.heatmap(df.select_dtypes(include=['int64','float64']).corr(), 
                 fmt='.2g', 
                 annot = True, 
                 vmin=-1,
                 vmax=1, 
                 center= 0, 
                 cmap= 'seismic', 
                 linecolor='black', 
                 linewidth=.5, 
                 annot_kws={"size": 9})
plt.xticks(rotation=45, 
           ha='right')

plt.title('\nSingapore HDB Correlation Matrix\n',
          fontsize=13)

# plt.savefig('correlation_matrix_baseline.png', 
#             bbox_inches='tight',
#             pad_inches=0.2, 
#             dpi=400)
fig.show();
# Out:
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# <br>

# %%
display(df.corr())
# Out:
#                                    storey_range_min  storey_range_max  \
# storey_range_min                               1.00              1.00
# storey_range_max                               1.00              1.00
# n_rooms                                        0.11              0.11
# floor_area_sqm                                 0.05              0.05
# lease_commence_date                            0.15              0.15
# remaining_lease_years                          0.07              0.06
# remaining_lease_months                         0.02              0.02
# resale_price                                   0.23              0.23
# price_per_sq_ft                                0.25              0.25
# price_per_sq_m                                 0.25              0.25
# price_per_sq_ft_per_lease_yr                   0.17              0.18
# price_per_sq_m_per_lease_yr                    0.17              0.18
# resale_price_norm                              0.21              0.21
# price_per_sq_ft_norm                           0.32              0.32
# price_per_sq_ft_per_lease_yr_norm              0.23              0.24
# price_per_sq_m_norm                            0.32              0.32
# price_per_sq_m_per_lease_yr_norm               0.23              0.24
# storey_range_avg                               1.00              1.00
#
#                                    n_rooms  floor_area_sqm  \
# storey_range_min                      0.11            0.05
# storey_range_max                      0.11            0.05
# n_rooms                               1.00            0.92
# floor_area_sqm                        0.92            1.00
# lease_commence_date                   0.48            0.43
# remaining_lease_years                 0.37            0.36
# remaining_lease_months                0.02            0.01
# resale_price                          0.61            0.60
# price_per_sq_ft                       0.17            0.11
# price_per_sq_m                        0.17            0.11
# price_per_sq_ft_per_lease_yr          0.03           -0.02
# price_per_sq_m_per_lease_yr           0.03           -0.02
# resale_price_norm                     0.79            0.83
# price_per_sq_ft_norm                  0.28            0.24
# price_per_sq_ft_per_lease_yr_norm     0.02           -0.01
# price_per_sq_m_norm                   0.28            0.24
# price_per_sq_m_per_lease_yr_norm      0.02           -0.01
# storey_range_avg                      0.11            0.05
#
#                                    lease_commence_date  remaining_lease_years  \
# storey_range_min                                  0.15                   0.07
# storey_range_max                                  0.15                   0.06
# n_rooms                                           0.48                   0.37
# floor_area_sqm                                    0.43                   0.36
# lease_commence_date                               1.00                   0.64
# remaining_lease_years                             0.64                   1.00
# remaining_lease_months                            0.09                   0.01
# resale_price                                      0.52                  -0.02
# price_per_sq_ft                                   0.38                  -0.27
# price_per_sq_m                                    0.38                  -0.27
# price_per_sq_ft_per_lease_yr                      0.09                  -0.57
# price_per_sq_m_per_lease_yr                       0.09                  -0.57
# resale_price_norm                                 0.38                   0.34
# price_per_sq_ft_norm                              0.20                   0.12
# price_per_sq_ft_per_lease_yr_norm                -0.20                  -0.48
# price_per_sq_m_norm                               0.20                   0.12
# price_per_sq_m_per_lease_yr_norm                 -0.20                  -0.48
# storey_range_avg                                  0.15                   0.07
#
#                                    remaining_lease_months  resale_price  \
# storey_range_min                                     0.02          0.23
# storey_range_max                                     0.02          0.23
# n_rooms                                              0.02          0.61
# floor_area_sqm                                       0.01          0.60
# lease_commence_date                                  0.09          0.52
# remaining_lease_years                                0.01         -0.02
# remaining_lease_months                               1.00          0.05
# resale_price                                         0.05          1.00
# price_per_sq_ft                                      0.04          0.83
# price_per_sq_m                                       0.04          0.83
# price_per_sq_ft_per_lease_yr                         0.03          0.70
# price_per_sq_m_per_lease_yr                          0.03          0.70
# resale_price_norm                                    0.04          0.69
# price_per_sq_ft_norm                                 0.03          0.53
# price_per_sq_ft_per_lease_yr_norm                    0.02          0.46
# price_per_sq_m_norm                                  0.03          0.53
# price_per_sq_m_per_lease_yr_norm                     0.02          0.46
# storey_range_avg                                     0.02          0.23
#
#                                    price_per_sq_ft  price_per_sq_m  \
# storey_range_min                              0.25            0.25
# storey_range_max                              0.25            0.25
# n_rooms                                       0.17            0.17
# floor_area_sqm                                0.11            0.11
# lease_commence_date                           0.38            0.38
# remaining_lease_years                        -0.27           -0.27
# remaining_lease_months                        0.04            0.04
# resale_price                                  0.83            0.83
# price_per_sq_ft                               1.00            1.00
# price_per_sq_m                                1.00            1.00
# price_per_sq_ft_per_lease_yr                  0.93            0.93
# price_per_sq_m_per_lease_yr                   0.93            0.93
# resale_price_norm                             0.34            0.34
# price_per_sq_ft_norm                          0.56            0.56
# price_per_sq_ft_per_lease_yr_norm             0.65            0.65
# price_per_sq_m_norm                           0.56            0.56
# price_per_sq_m_per_lease_yr_norm              0.65            0.65
# storey_range_avg                              0.25            0.25
#
#                                    price_per_sq_ft_per_lease_yr  \
# storey_range_min                                           0.17
# storey_range_max                                           0.18
# n_rooms                                                    0.03
# floor_area_sqm                                            -0.02
# lease_commence_date                                        0.09
# remaining_lease_years                                     -0.57
# remaining_lease_months                                     0.03
# resale_price                                               0.70
# price_per_sq_ft                                            0.93
# price_per_sq_m                                             0.93
# price_per_sq_ft_per_lease_yr                               1.00
# price_per_sq_m_per_lease_yr                                1.00
# resale_price_norm                                          0.19
# price_per_sq_ft_norm                                       0.44
# price_per_sq_ft_per_lease_yr_norm                          0.74
# price_per_sq_m_norm                                        0.44
# price_per_sq_m_per_lease_yr_norm                           0.74
# storey_range_avg                                           0.18
#
#                                    price_per_sq_m_per_lease_yr  \
# storey_range_min                                          0.17
# storey_range_max                                          0.18
# n_rooms                                                   0.03
# floor_area_sqm                                           -0.02
# lease_commence_date                                       0.09
# remaining_lease_years                                    -0.57
# remaining_lease_months                                    0.03
# resale_price                                              0.70
# price_per_sq_ft                                           0.93
# price_per_sq_m                                            0.93
# price_per_sq_ft_per_lease_yr                              1.00
# price_per_sq_m_per_lease_yr                               1.00
# resale_price_norm                                         0.19
# price_per_sq_ft_norm                                      0.44
# price_per_sq_ft_per_lease_yr_norm                         0.74
# price_per_sq_m_norm                                       0.44
# price_per_sq_m_per_lease_yr_norm                          0.74
# storey_range_avg                                          0.18
#
#                                    resale_price_norm  price_per_sq_ft_norm  \
# storey_range_min                                0.21                  0.32
# storey_range_max                                0.21                  0.32
# n_rooms                                         0.79                  0.28
# floor_area_sqm                                  0.83                  0.24
# lease_commence_date                             0.38                  0.20
# remaining_lease_years                           0.34                  0.12
# remaining_lease_months                          0.04                  0.03
# resale_price                                    0.69                  0.53
# price_per_sq_ft                                 0.34                  0.56
# price_per_sq_m                                  0.34                  0.56
# price_per_sq_ft_per_lease_yr                    0.19                  0.44
# price_per_sq_m_per_lease_yr                     0.19                  0.44
# resale_price_norm                               1.00                  0.73
# price_per_sq_ft_norm                            0.73                  1.00
# price_per_sq_ft_per_lease_yr_norm               0.42                  0.80
# price_per_sq_m_norm                             0.73                  1.00
# price_per_sq_m_per_lease_yr_norm                0.42                  0.80
# storey_range_avg                                0.21                  0.32
#
#                                    price_per_sq_ft_per_lease_yr_norm  \
# storey_range_min                                                0.23
# storey_range_max                                                0.24
# n_rooms                                                         0.02
# floor_area_sqm                                                 -0.01
# lease_commence_date                                            -0.20
# remaining_lease_years                                          -0.48
# remaining_lease_months                                          0.02
# resale_price                                                    0.46
# price_per_sq_ft                                                 0.65
# price_per_sq_m                                                  0.65
# price_per_sq_ft_per_lease_yr                                    0.74
# price_per_sq_m_per_lease_yr                                     0.74
# resale_price_norm                                               0.42
# price_per_sq_ft_norm                                            0.80
# price_per_sq_ft_per_lease_yr_norm                               1.00
# price_per_sq_m_norm                                             0.80
# price_per_sq_m_per_lease_yr_norm                                1.00
# storey_range_avg                                                0.23
#
#                                    price_per_sq_m_norm  \
# storey_range_min                                  0.32
# storey_range_max                                  0.32
# n_rooms                                           0.28
# floor_area_sqm                                    0.24
# lease_commence_date                               0.20
# remaining_lease_years                             0.12
# remaining_lease_months                            0.03
# resale_price                                      0.53
# price_per_sq_ft                                   0.56
# price_per_sq_m                                    0.56
# price_per_sq_ft_per_lease_yr                      0.44
# price_per_sq_m_per_lease_yr                       0.44
# resale_price_norm                                 0.73
# price_per_sq_ft_norm                              1.00
# price_per_sq_ft_per_lease_yr_norm                 0.80
# price_per_sq_m_norm                               1.00
# price_per_sq_m_per_lease_yr_norm                  0.80
# storey_range_avg                                  0.32
#
#                                    price_per_sq_m_per_lease_yr_norm  \
# storey_range_min                                               0.23
# storey_range_max                                               0.24
# n_rooms                                                        0.02
# floor_area_sqm                                                -0.01
# lease_commence_date                                           -0.20
# remaining_lease_years                                         -0.48
# remaining_lease_months                                         0.02
# resale_price                                                   0.46
# price_per_sq_ft                                                0.65
# price_per_sq_m                                                 0.65
# price_per_sq_ft_per_lease_yr                                   0.74
# price_per_sq_m_per_lease_yr                                    0.74
# resale_price_norm                                              0.42
# price_per_sq_ft_norm                                           0.80
# price_per_sq_ft_per_lease_yr_norm                              1.00
# price_per_sq_m_norm                                            0.80
# price_per_sq_m_per_lease_yr_norm                               1.00
# storey_range_avg                                               0.23
#
#                                    storey_range_avg
# storey_range_min                               1.00
# storey_range_max                               1.00
# n_rooms                                        0.11
# floor_area_sqm                                 0.05
# lease_commence_date                            0.15
# remaining_lease_years                          0.07
# remaining_lease_months                         0.02
# resale_price                                   0.23
# price_per_sq_ft                                0.25
# price_per_sq_m                                 0.25
# price_per_sq_ft_per_lease_yr                   0.18
# price_per_sq_m_per_lease_yr                    0.18
# resale_price_norm                              0.21
# price_per_sq_ft_norm                           0.32
# price_per_sq_ft_per_lease_yr_norm              0.23
# price_per_sq_m_norm                            0.32
# price_per_sq_m_per_lease_yr_norm               0.23
# storey_range_avg                               1.00

# %% [markdown]
# <br>

# %%
# let's rank from highest to lowest (comparing to our price_per_sq_m_norm feature)
correlations = df.corr()
correlations = correlations[['price_per_sq_m_norm']].sort_values(by='price_per_sq_m_norm', 
                                                                 ascending=False)
print(correlations.to_string())
# Out:
#                                    price_per_sq_m_norm
# price_per_sq_m_norm                               1.00
# price_per_sq_ft_norm                              1.00
# price_per_sq_ft_per_lease_yr_norm                 0.80
# price_per_sq_m_per_lease_yr_norm                  0.80
# resale_price_norm                                 0.73
# price_per_sq_ft                                   0.56
# price_per_sq_m                                    0.56
# resale_price                                      0.53
# price_per_sq_m_per_lease_yr                       0.44
# price_per_sq_ft_per_lease_yr                      0.44
# storey_range_max                                  0.32
# storey_range_avg                                  0.32
# storey_range_min                                  0.32
# n_rooms                                           0.28
# floor_area_sqm                                    0.24
# lease_commence_date                               0.20
# remaining_lease_years                             0.12
# remaining_lease_months                            0.03

# %%
cm = sns.light_palette("blue", as_cmap=True)
correlations.style.set_caption('Correlation Values Ranked').background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_2152e_row0_col0, #T_2152e_row1_col0 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_2152e_row2_col0, #T_2152e_row3_col0 {
#   background-color: #3131fd;
#   color: #f1f1f1;
# }
# #T_2152e_row4_col0 {
#   background-color: #4444fc;
#   color: #f1f1f1;
# }
# #T_2152e_row5_col0, #T_2152e_row6_col0 {
#   background-color: #6d6df9;
#   color: #f1f1f1;
# }
# #T_2152e_row7_col0 {
#   background-color: #7575f9;
#   color: #f1f1f1;
# }
# #T_2152e_row8_col0, #T_2152e_row9_col0 {
#   background-color: #8a8af8;
#   color: #f1f1f1;
# }
# #T_2152e_row10_col0, #T_2152e_row11_col0, #T_2152e_row12_col0 {
#   background-color: #a8a8f6;
#   color: #000000;
# }
# #T_2152e_row13_col0 {
#   background-color: #b1b1f6;
#   color: #000000;
# }
# #T_2152e_row14_col0 {
#   background-color: #bcbcf5;
#   color: #000000;
# }
# #T_2152e_row15_col0 {
#   background-color: #c8c8f5;
#   color: #000000;
# }
# #T_2152e_row16_col0 {
#   background-color: #dbdbf4;
#   color: #000000;
# }
# #T_2152e_row17_col0 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# </style>
# <table id="T_2152e_">
#   <caption>Correlation Values Ranked</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >price_per_sq_m_norm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2152e_level0_row0" class="row_heading level0 row0" >price_per_sq_m_norm</th>
#       <td id="T_2152e_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2152e_level0_row1" class="row_heading level0 row1" >price_per_sq_ft_norm</th>
#       <td id="T_2152e_row1_col0" class="data row1 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2152e_level0_row2" class="row_heading level0 row2" >price_per_sq_ft_per_lease_yr_norm</th>
#       <td id="T_2152e_row2_col0" class="data row2 col0" >0.799873</td>
#     </tr>
#     <tr>
#       <th id="T_2152e_level0_row3" class="row_heading level0 row3" >price_per_sq_m_per_lease_yr_norm</th>
#       <td id="T_2152e_row3_col0" class="data row3 col0" >0.799873</td>
#     </tr>
#     <tr>
#       <th id="T_2152e_level0_row4" class="row_heading level0 row4" >resale_price_norm</th>
#       <td id="T_2152e_row4_col0" class="data row4 col0" >0.726422</td>
#     </tr>
#     <tr>
#       <th id="T_2152e_level0_row5" class="row_heading level0 row5" >price_per_sq_ft</th>
#       <td id="T_2152e_row5_col0" class="data row5 col0" >0.558838</td>
#     </tr>
#     <tr>
#       <th id="T_2152e_level0_row6" class="row_heading level0 row6" >price_per_sq_m</th>
#       <td id="T_2152e_row6_col0" class="data row6 col0" >0.558838</td>
#     </tr>
#     <tr>
#       <th id="T_2152e_level0_row7" class="row_heading level0 row7" >resale_price</th>
#       <td id="T_2152e_row7_col0" class="data row7 col0" >0.527309</td>
#     </tr>
#     <tr>
#       <th id="T_2152e_level0_row8" class="row_heading level0 row8" >price_per_sq_m_per_lease_yr</th>
#       <td id="T_2152e_row8_col0" class="data row8 col0" >0.443894</td>
#     </tr>
#     <tr>
#       <th id="T_2152e_level0_row9" class="row_heading level0 row9" >price_per_sq_ft_per_lease_yr</th>
#       <td id="T_2152e_row9_col0" class="data row9 col0" >0.443894</td>
#     </tr>
#     <tr>
#       <th id="T_2152e_level0_row10" class="row_heading level0 row10" >storey_range_max</th>
#       <td id="T_2152e_row10_col0" class="data row10 col0" >0.321847</td>
#     </tr>
#     <tr>
#       <th id="T_2152e_level0_row11" class="row_heading level0 row11" >storey_range_avg</th>
#       <td id="T_2152e_row11_col0" class="data row11 col0" >0.321764</td>
#     </tr>
#     <tr>
#       <th id="T_2152e_level0_row12" class="row_heading level0 row12" >storey_range_min</th>
#       <td id="T_2152e_row12_col0" class="data row12 col0" >0.321568</td>
#     </tr>
#     <tr>
#       <th id="T_2152e_level0_row13" class="row_heading level0 row13" >n_rooms</th>
#       <td id="T_2152e_row13_col0" class="data row13 col0" >0.283866</td>
#     </tr>
#     <tr>
#       <th id="T_2152e_level0_row14" class="row_heading level0 row14" >floor_area_sqm</th>
#       <td id="T_2152e_row14_col0" class="data row14 col0" >0.243153</td>
#     </tr>
#     <tr>
#       <th id="T_2152e_level0_row15" class="row_heading level0 row15" >lease_commence_date</th>
#       <td id="T_2152e_row15_col0" class="data row15 col0" >0.195718</td>
#     </tr>
#     <tr>
#       <th id="T_2152e_level0_row16" class="row_heading level0 row16" >remaining_lease_years</th>
#       <td id="T_2152e_row16_col0" class="data row16 col0" >0.117078</td>
#     </tr>
#     <tr>
#       <th id="T_2152e_level0_row17" class="row_heading level0 row17" >remaining_lease_months</th>
#       <td id="T_2152e_row17_col0" class="data row17 col0" >0.029003</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# > This makes sense.  price_per_sq_ft_norm should be 100% correlated with price_per_sq_m_norm, etc.  Any correlation higher than 0.80 is a measure of collinearity.  Some features are mathematically derived from others at this point, to be filtered later
