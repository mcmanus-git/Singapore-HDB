# %%
import pandas as pd
from MyCreds.mycreds import Capstone_AWS_PG
from sqlalchemy import create_engine
import geopandas as gpd

query = 'select * from sg_buildings_postal_geo;'

engine = create_engine(f'postgresql+psycopg2://{Capstone_AWS_PG.username}:{Capstone_AWS_PG.password}@{Capstone_AWS_PG.host}/capstone', echo=False)

sql_alc_cnxn = engine.connect()
postal = gpd.read_postgis(query, sql_alc_cnxn, geom_col='geometry')
postal
# Out:
#             id                                            address   blk_no  \
# 0            0  101A BAYFRONT AVENUE TEMPORARY SITE OFFICE SIN...     101A
# 1            1  1 STRAITS BOULEVARD SINGAPORE CHINESE CULTURAL...        1
# 2            2  11A STRAITS BOULEVARD TEMPORARY SITE OFFICE SI...      11A
# 3            3  2 CENTRAL BOULEVARD IOI CENTRAL BOULEVARD TOWE...        2
# 4            4  21 PARK STREET DBS MARINA BAY MRT STATION SING...       21
# ...        ...                                                ...      ...
# 142881  142881                  100A KRANJI LOOP SINGAPORE 887327     100A
# 142882  142882              A PASIR PANJANG ROAD SINGAPORE 887328        A
# 142883  142883                       PULAU BUKOM SINGAPORE 903808     None
# 142884  142884  GATE C7 AIRPORT CARGO ROAD CHANGI ANIMAL AND P...  GATE C7
# 142885  142885  AIRPORT BOULEVARD CHANGI AIRPORT TERMINAL 2 BU...     None
#
# ...

# %%
# Out:
# array(['1990_01_309_ANG_MO_KIO_AVE_1_10_TO_12'], dtype=object)

# %%
import folium

# %%
base_map = folium.Map(location=[1.3521, 103.8198], zoom_start=12)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
y = [geo.y for geo in postal['geometry'].values]
x = [geo.x for geo in postal['geometry'].values]
# pts = [j for i in zip(y, x) for j in i]

base_map = folium.Map(location=[1.3521, 103.8198], zoom_start=12)

for i in range(100):
    folium.Marker(location=[x[i], y[i]],
                  icon=folium.Icon(color="red", # Outside Color
                                   icon_color='white', # Icon Color
                                   icon='info-sign' # Type of Icon
                                   )
                  ).add_to(base_map)

base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
